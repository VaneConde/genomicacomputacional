# %%
compra=250 
if compra >100:
    print (compra*.90)
# Out:
# 225.0

# %%
b = 36 
h = 34
a = b * h/2
print(a)
# Out:
# 612.0

# %%
kg = 56
m2 = 1.62**2 
IMC = kg /m2 
print (IMC)
# Out:
# 21.338210638622158
